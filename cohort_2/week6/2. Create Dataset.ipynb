# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Week 6 - Systematically Improving Your Rag Application
#
# > If you haven't already, please run the [1. Evaluate Tools](1. Evaluate Tools.ipynb) notebook to understand how to evaluate your application's tool calling capabilities. That will help you understand what we're doing here in this notebook.
#
# ## Generating Synthetic Data
#
# We want to evaluate the recall of our application's tool calling capabilities. To do so, we'll generate a synthetic dataset of queries using a small subset of Raycast's extensions. We'll do so in 3 steps
#
# 1. **Extracting Commands** : We'll first start by extracting the commands from the `package.json` file from the extensions we'd like to generate synthetic queries for
# 2. **Generating Queries** : We'll then generate a set of test queries for each of these commands
# 3. **Evaluating Recall** : We'll then evaluate the precision and recall of our application's tool calling capabilities for each of these queries
#
# We'll do so by extracting the commands from the `package.json` files for the extensions we'd like to run our analysis on. We'll then generate a set of test queries for each of these commands and evaluate the recall for each command and query.

# %%
VOICE_COMMAND_EXTENSIONS = [
    "google-search",
    "jira-search",
    "notion",
    "apple-notes",
    "obsidian",
    "calendar",
    "wikipedia",
    "youtube",
    "amazon-search",
    "reddit-search",
    "spotify-player",
    "1password",
]

# %%
import os
import requests
import json

def ensure_directory(directory: str):
    """Ensure the given directory exists."""
    if not os.path.exists(directory):
        os.makedirs(directory)


def fetch_package_json(extension_name: str) -> str:
    """Generate the URL to fetch the package.json of the extension."""
    return f"https://raw.githubusercontent.com/raycast/extensions/main/extensions/{extension_name}/package.json"


def download_package_json(extension_name: str, output_dir: str) -> bool:
    """Download the package.json for a specific extension."""
    url = fetch_package_json(extension_name)
    response = requests.get(url)
    if response.status_code == 200:
        with open(f"{output_dir}/{extension_name}.json", "w") as file:
            file.write(response.text)
        print(f"Downloaded package.json for {extension_name}")
        return True
    else:
        print(f"Failed to download package.json for {extension_name}")
        return False

def extract_commands(extension_name: str, input_dir: str) -> list:
    """Extract commands from a package.json file."""
    commands = []
    file_path = f"{input_dir}/{extension_name}.json"
    try:
        with open(file_path, "r") as file:
            package_data = json.load(file)
            for command in package_data.get("commands", []):
                commands.append(
                    {
                        "name": command["name"],
                        "description": command.get(
                            "description", "No description provided"
                        ),
                        "extension": extension_name,
                        "plugin_description": package_data.get(
                            "description", "No description provided"
                        ),
                    }
                )
    except FileNotFoundError:
        print(f"File not found for {extension_name}")
    except json.JSONDecodeError:
        print(f"Failed to decode JSON for {extension_name}")
    return commands

# %% [markdown]
# We can then extract the commands from the `package.json` files and download them into a single `json` file that we can use to generate our synthetic dataset.

# %%
output_dir = "packages"
ensure_directory(output_dir)

# Step 1: Download package.json files
for extension in VOICE_COMMAND_EXTENSIONS:
    download_package_json(extension, output_dir)

# Step 2: Extract and display commands
all_commands = []
for extension in VOICE_COMMAND_EXTENSIONS:
    commands = extract_commands(extension, output_dir)
    all_commands.extend(commands)

# Save extracted commands to a JSON file
with open("extracted_commands.json", "w") as file:
    json.dump(all_commands, file, indent=2)

# Print extracted commands to console
for command in all_commands:
    print(f"[{command['extension']}] {command['name']}: {command['description']}")
# Out:
# Downloaded package.json for google-search
# Downloaded package.json for jira-search
# Downloaded package.json for notion
# Downloaded package.json for apple-notes
# Downloaded package.json for obsidian
# Downloaded package.json for calendar
# Downloaded package.json for wikipedia
# Downloaded package.json for youtube
# Downloaded package.json for amazon-search
# Downloaded package.json for reddit-search
# Downloaded package.json for spotify-player
# Downloaded package.json for 1password
# [google-search] index: Google search with autosuggestions
# [google-search] searchSelectText: Google search with selected text
# [jira-search] issue: Search Jira issues by text, type and project
# [jira-search] board: Search Jira boards by title
# [jira-search] filter: Search Jira filters by title
# [jira-search] project: Search Jira projects by title
# [jira-search] image: Delete cached Jira images and reload them on next search
# [notion] create-database-page: Create a page in a Notion database.
# [notion] search-page: Search for Notion databases and pages.
# [notion] quick-capture: Capture something and put it out in a Notion page.
# [notion] add-text-to-page: Append or prepend text, along with date, to a Notion page.
# [apple-notes] index: Search through your Apple notes.
# [apple-notes] new: Create a new note in your Apple Notes.
# [apple-notes] ai: Create a new note filled with AI in your Apple notes.
# [apple-notes] menu-bar: View your recent and pinned Apple notes in the menu bar.
# [apple-notes] add-text: Add some text to an Apple note.
# [apple-notes] view-selected-note: View the currently selected note in Raycast.
# [obsidian] searchNoteCommand: Search, open, view, copy, paste and edit any note in Obsidian.
# [obsidian] starredNotesCommand: Search, open, view, copy, paste and edit bookmarked notes in Obsidian.
# [obsidian] openVaultCommand: Open a vault in Obsidian.
# [obsidian] dailyNoteAppendCommand: Append text to your daily note
# [obsidian] dailyNoteCommand: Open daily note in Obsidian. Will create new daily note when it doesn't exist yet.
# [obsidian] createNoteCommand: Create new note
# [obsidian] randomNoteCommand: Open random note
# [obsidian] searchMedia: Search for media in your vault
# [obsidian] obsidianMenuBar: See your pinned notes at a glance and control actions from the menu bar.
# [obsidian] appendTaskCommand: Append a task to a note of your choice
# [calendar] index: Shows calendar for a month
# [wikipedia] search-page: Search Wikipedia pages by title
# [wikipedia] open-page: Open Wikipedia page in Raycast
# [wikipedia] random-page: Open a random Wikipedia page in browser
# [wikipedia] featured-page: Open today's featured Wikipedia page in browser
# [youtube] search-videos: Search YouTube Videos
# [youtube] search-channel: Search YouTube Channels
# [youtube] popular-videos: Show Popular YouTube Videos
# [amazon-search] index: Amazon search with autosuggestions
# [reddit-search] index: Searches Reddit and lists the results with the option to sort, show more, or show the results on Reddit.
# [spotify-player] search: A single unified search command. Search for artists, albums, songs, playlists, podcasts, and episodes. Use the dropdown menu to filter your search to a specific category. Each category offers contextual actions, so you can dive deeper into the search.
# [spotify-player] yourLibrary: See your saved artists, albums, songs, playlists, and podcasts. Similar to the "Search" command, it includes a category dropdown and contextual actions.
# [spotify-player] nowPlaying: See what's currently playing. Use the actions (⌘ K) for further actions, such as Play/Pause, Like/Dislike, Skip, Start Radio, Add to Playlist, Connect Device and more.
# [spotify-player] nowPlayingMenuBar: See what's currently playing in your Menu Bar. Click for further actions, such as Play/Pause, Like/Dislike, Skip, Start Radio, Add to Playlist, Connect Device and more. Refreshes every 10 seconds.
# [spotify-player] togglePlayPause: Toggle the playback of the current song.
# [spotify-player] addPlayingSongToPlaylist: Adds the current song to a playlist of your choice.
# [spotify-player] removeSongFromPlaylist: Remove the current song from a playlist of your choice.
# [spotify-player] next: Skip to the next song/episode.
# [spotify-player] previous: Skip to the previous song/episode.
# [spotify-player] like: Like the current song.
# [spotify-player] dislike: Dislike the current song.
# [spotify-player] devices: Select a device to play music on.
# [spotify-player] volume: Set the volume to an arbitrary percent.
# [spotify-player] volume0: Mute the volume.
# [spotify-player] volume25: Set the volume to 25%.
# [spotify-player] volume50: Set the volume to 50%.
# [spotify-player] volume75: Set the volume to 75%.
# [spotify-player] volume100: Set the volume to 100%.
# [spotify-player] volumeDown: Turn the volume down by 10%.
# [spotify-player] volumeUp: Turn the volume up by 10%.
# [spotify-player] toggleShuffle: Toggle shuffle.
# [spotify-player] cycleRepeat: Cycle the repeat state between off, context (meaning the current playlist/album), and track.
# [spotify-player] replay: Replay the current song/episode form the beginning.
# [spotify-player] current-track: Show the current song/episode state.
# [spotify-player] startRadio: Start a radio station based on the current song.
# [spotify-player] copyUrl: Copy the URL of the current song/episode.
# [spotify-player] justPlay: Quickly start playing a song based on your query.
# [spotify-player] queue: See your queue.
# [spotify-player] generatePlaylist: Generate a Spotify playlist using Raycast AI.
# [spotify-player] startDJ: Start the DJ.
# [1password] item-list: List of all your 1Password items. Then open in your default browser, view items in 1Password, or open items in 1Password for editing.
# [1password] renew-auth: Renews the authorization each 9 minutes. Avoiding the prompt for user's password each use after 10 minutes.
# [1password] vault-list: List of all your 1Password vaults. Then open all items related to each vault.
# [1password] generate-password: Generate a random password with 1Password.
